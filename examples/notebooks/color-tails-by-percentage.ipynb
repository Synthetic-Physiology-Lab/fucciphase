# %% [markdown]
# # Visualising phase distributions as colour tails
#
# This notebook focuses on **visualising cell-cycle phase distributions** as
# “colour tails”: plots where each time point is represented by a bar or tail
# coloured by phase percentage.
#
# In this notebook you will:
#
# - load FUCCIphase output tables,
# - compute phase percentages over time or conditions,
# - generate colour-tail plots suitable for figures and summaries.
#
# Use this notebook if you already have FUCCIphase output and want to produce
# compact, visual summaries of phase distributions.

# %% [markdown]
# Use this notebook as an example and adapt it to fit your own data.
# You will need:
#
# 1. An image file
# 2. Segmentation labels
# 3. A TrackMate XML file with the tracking results
# 4. A file with the details of the FUCCI sensor
# 5. A file with the FUCCI reference intensity curve

# %%
import json

import napari
import pandas as pd
import vispy
from aicsimageio import AICSImage
from napari_animation import Animation
from skimage.io import imread

from fucciphase import process_trackmate
from fucciphase.napari import add_trackmate_data_to_viewer, pandas_df_to_napari_tracks
from fucciphase.phase import (
    estimate_percentage_by_subsequence_alignment,
)
from fucciphase.sensor import FUCCISASensor
from fucciphase.utils import postprocess_estimated_percentages

# %%
cyan_channel = "MEAN_INTENSITY_CH2"
magenta_channel = "MEAN_INTENSITY_CH1"
regex = r"Track_[0-9]+\\.[a-z]+"
timestep = 0.25  # in hours

reference_file = "../reproducibility/inputs/hacat_fucciphase_reference.csv"
sensor_file = "../example_data/fuccisa_hacat.json"
track_file = "../reproducibility/inputs/merged_linked.ome.xml"
reference_df = pd.read_csv(reference_file)
reference_df.rename(
    columns={"cyan": cyan_channel, "magenta": magenta_channel}, inplace=True
)

# %%
with open(sensor_file) as fp:
    sensor_properties = json.load(fp)
sensor = FUCCISASensor(**sensor_properties)

# %%
label_file = "../reproducibility/inputs/labels.tif" # you need to provide a label file
labels = imread(label_file)
image = AICSImage("../reproducibility/inputs/downscaled_hacat.ome.tif")
#scale = (image.physical_pixel_sizes.Y, image.physical_pixel_sizes.X)
pixel_size=0.544
scale = (pixel_size,pixel_size)
cyan = image.get_image_dask_data("TYX", C=1)
magenta = image.get_image_dask_data("TYX", C=0)
#actin = image.get_image_dask_data("TYX", C=1)

# %% [markdown]
# ## Get tracks

# %%
track_df = process_trackmate(
    track_file,
    channels=[cyan_channel, magenta_channel],
    sensor=sensor,
    thresholds=[0.1, 0.1],
    generate_unique_tracks=True,
)
# Out:
# C:\Users\SPL_ImageAnalysis-WS\Desktop\fucciphase\src\fucciphase\utils\track_postprocessing.py:352: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["UNIQUE_TRACK_ID"].update(new_track_ids)

# %%
track_df["UNIQUE_TRACK_ID"].unique()
# Out:
# array([ 2,  3,  0,  1, 11, 20, 17, 14, 10, 12, 13, 22, 21, 19, 18, 16, 15])

# %%
postprocess_estimated_percentages(
    track_df, percentage_column="CELL_CYCLE_PERC", track_id_name="UNIQUE_TRACK_ID"
)
estimate_percentage_by_subsequence_alignment(
    track_df,
    dt=0.25,
    channels=[cyan_channel, magenta_channel],
    reference_data=reference_df,
    track_id_name="UNIQUE_TRACK_ID",
)
postprocess_estimated_percentages(
    track_df, percentage_column="CELL_CYCLE_PERC_DTW", track_id_name="UNIQUE_TRACK_ID"
)

# %%
viewer = napari.Viewer()
# Out:
# C:\Users\SPL_ImageAnalysis-WS\anaconda3\envs\fucciphase_run\lib\site-packages\napari\plugins\_plugin_manager.py:555: UserWarning: Plugin 'bbii-decon' has already registered a function widget 'bbii deconvolution' which has now been overwritten
#   warn(message=warn_message)

# %%
add_trackmate_data_to_viewer(
    track_df,
    viewer,
    scale=scale,
    image_data=[cyan, magenta],
    colormaps=["cyan", "magenta"],
    labels=labels,
    cycle_percentage_id="CELL_CYCLE_PERC_DTW",
    label_id_name="MEDIAN_INTENSITY_CH3",
    textkwargs={"size": 16},
)

# %%
viewer.add_image(actin, blending="additive", scale=scale)

# %%
colormap = vispy.color.colormap.MatplotlibColormap("cool")

# %% [markdown]
# # Normalise percentage
#
# This step is needed to color the tails with respect to the cell cycle.

# %%
track_df["CELL_CYCLE_PERC_NORM"] = track_df["CELL_CYCLE_PERC_DTW"] / 100.0

# %%
pandas_df_to_napari_tracks(
    track_df,
    viewer,
    unique_track_id_name="UNIQUE_TRACK_ID",
    frame_id_name="FRAME",
    position_x_name="POSITION_X",
    position_y_name="POSITION_Y",
    feature_name="CELL_CYCLE_PERC_NORM",
    colormaps_dict={"CELL_CYCLE_PERC_NORM": colormap},
)

# %% [markdown]
# # Add a time stamp
#
# ## Color the tails
#
# Choose the color of the track tails according to the
# `CELL_CYCLE_PERC_NORM` by clicking on the respective entry
# in the GUI.
#
# More details here:
# https://napari.org/0.4.18/howtos/layers/tracks.html#setting-the-track-color-with-properties

# %%
old_time = -1


def update_slider(event):
    """Update time stamp."""
    time = viewer.dims.current_step[0]
    global old_time
    if time != old_time:
        old_time = time
    else:
        return
    time = 15.0 * time
    viewer.text_overlay.text = f"{round(time)} min "


viewer.text_overlay.color = "white"
viewer.text_overlay.blending = "translucent_no_depth"
viewer.text_overlay.position = "top_left"
viewer.text_overlay.font_size = 18
viewer.text_overlay.visible = True
viewer.dims.events.current_step.connect(update_slider)
# Out:
# <function __main__.update_slider(event)>

# %% [markdown]
# # Save a MP4 video

# %%
animation = Animation(viewer)

# start animation on first frame
viewer.dims.current_step = (0, 0, 0)
animation.capture_keyframe()
# last frame
viewer.dims.current_step = (labels.shape[0] - 1, 0, 0)
animation.capture_keyframe(steps=labels.shape[0] - 1)
animation.animate(
    "movie_tails_percentages.mp4", canvas_only=True, fps=4, quality=9, scale_factor=1.0
)
# Out:
# Rendering frames...
#   0%|          | 0/121 [00:00<?, ?it/s]IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (3081, 1301) to (3088, 1312) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
#  10%|▉         | 12/121 [00:02<00:23,  4.56it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 9
#       7 viewer.dims.current_step = (labels.shape[0] - 1, 0, 0)
#       8 animation.capture_keyframe(steps=labels.shape[0] - 1)
# ----> 9 animation.animate(
#      10     "movie_tails_percentages.mp4", canvas_only=True, fps=4, quality=9, scale_factor=1.0
#      11 )
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari_animation\animation.py:237, in Animation.animate(self, filename, fps, quality, file_format, canvas_only, scale_factor)
#     235 sleep(0.05)
#     236 with tqdm(total=n_frames) as pbar:
# --> 237     for frame_index, image in enumerate(frame_generator):
#     238         if save_as_folder is True:
#     239             frame_filename = (
#     240                 folder_path / f"{file_path.stem}_{frame_index:06d}.png"
#     241             )
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari_animation\frame_sequence.py:153, in FrameSequence.iter_frames(self, viewer, canvas_only, scale_factor)
#     151 """Iterate over interpolated viewer states, and yield rendered frames."""
#     152 for _i, state in enumerate(self):
# --> 153     frame = state.render(viewer, canvas_only=canvas_only)
#     154     if scale_factor not in (None, 1):
#     155         from scipy import ndimage as ndi
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari_animation\viewer_state.py:84, in ViewerState.render(self, viewer, canvas_only)
#      66 def render(
#      67     self, viewer: napari.viewer.Viewer, canvas_only: bool = True
#      68 ) -> np.ndarray:
#      69     """Render this ViewerState to an image.
#      70
#      71     Parameters
#    (...)
#      82         An RGBA image of shape (h, w, 4).
#      83     """
# ---> 84     self.apply(viewer)
#      85     return viewer.screenshot(canvas_only=canvas_only, flash=False)
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari_animation\viewer_state.py:53, in ViewerState.apply(self, viewer)
#      44 """Update `viewer` to match this ViewerState.
#      45
#      46 Parameters
#    (...)
#      49     A napari viewer. (viewer state will be directly modified)
#      50 """
#      52 viewer.camera.update(self.camera)
# ---> 53 viewer.dims.update(self.dims)
#      55 for layer_name, layer_state in self.layers.items():
#      56     layer = viewer.layers[layer_name]
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari\utils\events\evented_model.py:413, in EventedModel.update(self, values, recurse)
#     411             field.update(value, recurse=recurse)
#     412         else:
# --> 413             setattr(self, key, value)
#     415 if block.count:
#     416     self.events(Event(self))
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari\utils\events\evented_model.py:333, in EventedModel.__setattr__(self, name, value)
#     330 if are_equal(after, before):
#     331     # no change
#     332     return
# --> 333 emitter(value=after)  # emit event
#     335 # emit events for any dependent computed properties as well
#     336 for dep, value_ in before_deps.items():
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari\utils\events\event.py:763, in EventEmitter.__call__(self, *args, **kwargs)
#     760     self._block_counter.update([cb])
#     761     continue
# --> 763 self._invoke_callback(cb, event if pass_event else None)
#     764 if event.blocked:
#     765     break
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari\utils\events\event.py:790, in EventEmitter._invoke_callback(self, cb, event)
#     788         cb(event)
#     789     else:
# --> 790         cb()
#     791 except Exception as e:  # noqa: BLE001
#     792     # dead Qt object with living python pointer. not importing Qt
#     793     # here... but this error is consistent across backends
#     794     if (
#     795         isinstance(e, RuntimeError)
#     796         and 'C++' in str(e)
#     797         and str(e).endswith(('has been deleted', 'already deleted.'))
#     798     ):
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari\components\viewer_model.py:393, in ViewerModel._update_layers(self, layers)
#     391 layers = layers or self.layers
#     392 for layer in layers:
# --> 393     layer._slice_dims(
#     394         self.dims.point, self.dims.ndisplay, self.dims.order
#     395     )
#     396 position = list(self.cursor.position)
#     397 for ind in self.dims.order[: -self.dims.ndisplay]:
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari\layers\base\base.py:1109, in Layer._slice_dims(self, point, ndisplay, order)
#    1106 self._slice_input = slice_input
#    1108 # Update the point values
# -> 1109 self.refresh()
#    1110 self._reset_editable()
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari\layers\base\base.py:1299, in Layer.refresh(self, event)
#    1297 self.set_view_slice()
#    1298 self.events.set_data()
# -> 1299 self._update_thumbnail()
#    1300 self._set_highlight(force=True)
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\napari\layers\image\image.py:1292, in Image._update_thumbnail(self)
#    1290         colormapped = np.concatenate([downsampled, alpha], axis=2)
#    1291 else:
# -> 1292     downsampled = ndi.zoom(
#    1293         image, zoom_factor, prefilter=False, order=0
#    1294     )
#    1295     low, high = self.contrast_limits
#    1296     downsampled = np.clip(downsampled, low, high)
#
# File ~\anaconda3\envs\fucciphase_run\lib\site-packages\scipy\ndimage\_interpolation.py:819, in zoom(input, zoom, output, order, mode, cval, prefilter, grid_mode)
#     815 zoom = numpy.divide(zoom_nominator, zoom_div,
#     816                     out=numpy.ones_like(input.shape, dtype=numpy.float64),
#     817                     where=zoom_div != 0)
#     818 zoom = numpy.ascontiguousarray(zoom)
# --> 819 _nd_image.zoom_shift(filtered, zoom, None, output, order, mode, cval, npad,
#     820                      grid_mode)
#     821 return output
#
# KeyboardInterrupt:
